# %%
import pandas as pd
import numpy as np

from datetime import datetime
from datetime import time

pd.options.display.max_columns = None

# %% [markdown]
# # Pitstop comparison by team
# Throughout a race, a drive needs to routinely go to their team's pit stall for a quick maintenence, change of tires, or conduct repairs on the vehicle [Pit Stop Reference](https://statathlon.com/analysis-of-the-pit-stop-strategy-in-f1/#:~:text=In%20F1%2C%20a%20pit%20stop,connected%20to%20the%20main%20track.).
# When a driver enters the pit stall, this is referred to as a "pitstop."
# Pitstops are crucial for team success. The faster the pit crew can perform a pitstop, the faster the driver can return to the race.
# A slow pitstop can waste valuable time, and possibly cost the team their lead.
# Each F1 team has two drivers. We will be looking at the Ferrari F1 team.
# We will find the fastest pitstop time for each driver during every race.
# A pitstop will include the time it takes the driver to get to the pit, change their tires, and get back on the track.
# The pitstop time will be calculated in seconds (s).

# %% [markdown]
# # F1 2023 Season
# The 2023 Season started in Bahrain on 2023-03-05.
# The 2023 Season ended in Abu Dhabi on 2023-11-26.
# There are a total of 23 rounds or race events.

# %%
# Pit stop time by team and race (reference back using raceId and DriverId)
# Starting df, will merge information from other 
pit_stops_df = pd.read_csv('f1db_csv/pit_stops.csv', index_col=False) # pitstop data

drivers_df = pd.read_csv('f1db_csv/drivers.csv', index_col=False) # F1 Drivers 

constructors_df = pd.read_csv('f1db_csv/constructors.csv', index_col=False) # F1 teams

races_df = pd.read_csv('f1db_csv/races.csv', index_col=False) # F1 Races

circuit_df = pd.read_csv('f1db_csv/circuits.csv', index_col=False) # F1 Tracks

results_df = pd.read_csv('f1db_csv/results.csv', index_col=False)

# %%
pit_stops_df = pit_stops_df.drop(columns=['time'])
pit_stops_df = pit_stops_df.rename(columns={'duration': 'seconds'})
pit_stops_df
# Out:
#        raceId  driverId  stop  lap seconds  milliseconds
# 0         841       153     1    1  26.898         26898
# 1         841        30     1    1  25.021         25021
# 2         841        17     1   11  23.426         23426
# 3         841         4     1   12  23.251         23251
# 4         841        13     1   13  23.842         23842
# ...       ...       ...   ...  ...     ...           ...
# 10853    1128       840    48    3  28.211         28211
# 10854    1128         1    51    2  24.232         24232
# 10855    1128       830    52    2  23.813         23813
# 10856    1128       858    57    2  24.384         24384
# 10857    1128       855    70    2  24.367         24367
#
# [10858 rows x 6 columns]

# %%
# drivers df cleaning
drivers_df = drivers_df[['driverId', 'number', 'forename', 'surname', 'dob']]
drivers_df = drivers_df.rename(columns={'forename': 'firstname', 'surname': 'lastname'})
drivers_df
# Out:
#      driverId number firstname    lastname         dob
# 0           1     44     Lewis    Hamilton  1985-01-07
# 1           2     \N      Nick    Heidfeld  1977-05-10
# 2           3      6      Nico     Rosberg  1985-06-27
# 3           4     14  Fernando      Alonso  1981-07-29
# 4           5     \N    Heikki  Kovalainen  1981-10-19
# ..        ...    ...       ...         ...         ...
# 854       856     21      Nyck    de Vries  1995-02-06
# 855       857     81     Oscar     Piastri  2001-04-06
# 856       858      2     Logan    Sargeant  2000-12-31
# 857       859     40      Liam      Lawson  2002-02-11
# 858       860     38    Oliver     Bearman  2005-05-08
#
# [859 rows x 5 columns]

# %%
constructors_df = constructors_df[['constructorId', 'name']]
constructors_df = constructors_df.rename(columns={'name': 'teamname'})
constructors_df
# Out:
#      constructorId        teamname
# 0                1         McLaren
# 1                2      BMW Sauber
# 2                3        Williams
# 3                4         Renault
# 4                5      Toro Rosso
# ..             ...             ...
# 207            210    Haas F1 Team
# 208            211    Racing Point
# 209            213      AlphaTauri
# 210            214  Alpine F1 Team
# 211            215      RB F1 Team
#
# [212 rows x 2 columns]

# %%
# races df cleaning
races_df = races_df.loc[races_df['year'] == 2023].reset_index(drop=True) # only grabbing races during 2023
races_df = races_df[['raceId', 'year', 'round', 'circuitId', 'name', 'date']]
races_df = races_df.rename(columns={'name': 'gpname'}) # set up grand prix name
races_df
# Out:
#     raceId  year  round  circuitId                    gpname        date
# 0     1098  2023      1          3        Bahrain Grand Prix  2023-03-05
# 1     1099  2023      2         77  Saudi Arabian Grand Prix  2023-03-19
# 2     1100  2023      3          1     Australian Grand Prix  2023-04-02
# 3     1101  2023      4         73     Azerbaijan Grand Prix  2023-04-30
# 4     1102  2023      5         79          Miami Grand Prix  2023-05-07
# 5     1104  2023      6          6         Monaco Grand Prix  2023-05-28
# 6     1105  2023      7          4        Spanish Grand Prix  2023-06-04
# 7     1106  2023      8          7       Canadian Grand Prix  2023-06-18
# 8     1107  2023      9         70       Austrian Grand Prix  2023-07-02
# 9     1108  2023     10          9        British Grand Prix  2023-07-09
# 10    1109  2023     11         11      Hungarian Grand Prix  2023-07-23
# 11    1110  2023     12         13        Belgian Grand Prix  2023-07-30
# 12    1111  2023     13         39          Dutch Grand Prix  2023-08-27
# 13    1112  2023     14         14        Italian Grand Prix  2023-09-03
# 14    1113  2023     15         15      Singapore Grand Prix  2023-09-17
# 15    1114  2023     16         22       Japanese Grand Prix  2023-09-24
# 16    1115  2023     17         78          Qatar Grand Prix  2023-10-08
# 17    1116  2023     18         69  United States Grand Prix  2023-10-22
# 18    1117  2023     19         32    Mexico City Grand Prix  2023-10-29
# 19    1118  2023     20         18      São Paulo Grand Prix  2023-11-05
# 20    1119  2023     21         80      Las Vegas Grand Prix  2023-11-19
# 21    1120  2023     22         24      Abu Dhabi Grand Prix  2023-11-26

# %%
# we probably don't need this dataframe until the end
## Nice info 
circuit_df = circuit_df[['circuitId', 'circuitRef', 'name', 'location', 'country']]
circuit_df = circuit_df.rename(columns={'name': 'gpname'}) # set up grand prix name
circuit_df
# Out:
#     circuitId   circuitRef                                gpname  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country
# 0      Melbourne     Australia
# 1   Kuala Lumpur      Malaysia
# 2         Sakhir       Bahrain
# 3       Montmeló         Spain
# 4       Istanbul        Turkey
# ..           ...           ...
# 72      Portimão      Portugal
# 73       Mugello         Italy
# 74        Jeddah  Saudi Arabia
# 75     Al Daayen         Qatar
# 76         Miami           USA
#
# [77 rows x 5 columns]

# %% [markdown]
# # Combining dataframes to get the necessary information:
# 1. Driver Information by Team
# 1. Team/Constructor Information
# 1. Pit Stop Time
# 1. Sort by Race and Circuit (Race Track)

# %%
# all races in 2023
races_df
# Out:
#     raceId  year  round  circuitId                    gpname        date
# 0     1098  2023      1          3        Bahrain Grand Prix  2023-03-05
# 1     1099  2023      2         77  Saudi Arabian Grand Prix  2023-03-19
# 2     1100  2023      3          1     Australian Grand Prix  2023-04-02
# 3     1101  2023      4         73     Azerbaijan Grand Prix  2023-04-30
# 4     1102  2023      5         79          Miami Grand Prix  2023-05-07
# 5     1104  2023      6          6         Monaco Grand Prix  2023-05-28
# 6     1105  2023      7          4        Spanish Grand Prix  2023-06-04
# 7     1106  2023      8          7       Canadian Grand Prix  2023-06-18
# 8     1107  2023      9         70       Austrian Grand Prix  2023-07-02
# 9     1108  2023     10          9        British Grand Prix  2023-07-09
# 10    1109  2023     11         11      Hungarian Grand Prix  2023-07-23
# 11    1110  2023     12         13        Belgian Grand Prix  2023-07-30
# 12    1111  2023     13         39          Dutch Grand Prix  2023-08-27
# 13    1112  2023     14         14        Italian Grand Prix  2023-09-03
# 14    1113  2023     15         15      Singapore Grand Prix  2023-09-17
# 15    1114  2023     16         22       Japanese Grand Prix  2023-09-24
# 16    1115  2023     17         78          Qatar Grand Prix  2023-10-08
# 17    1116  2023     18         69  United States Grand Prix  2023-10-22
# 18    1117  2023     19         32    Mexico City Grand Prix  2023-10-29
# 19    1118  2023     20         18      São Paulo Grand Prix  2023-11-05
# 20    1119  2023     21         80      Las Vegas Grand Prix  2023-11-19
# 21    1120  2023     22         24      Abu Dhabi Grand Prix  2023-11-26

# %%
# using the results dataframe because it uses the Driver ID & Constructor (Team) ID
results_df = results_df[['raceId', 'driverId', 'constructorId']]
results_df = results_df.drop_duplicates().reset_index(drop=True)
results_df
# Out:
#        raceId  driverId  constructorId
# 0          18         1              1
# 1          18         2              2
# 2          18         3              3
# 3          18         4              4
# 4          18         5              1
# ...       ...       ...            ...
# 26380    1129       832              6
# 26381    1129       848              3
# 26382    1129       815              9
# 26383    1129       844              6
# 26384    1129       858              3
#
# [26385 rows x 3 columns]

# %%
missing_driver_missing_team_ps = pd.merge(pit_stops_df, results_df, on=['raceId', 'driverId'], how='inner')
missing_driver_missing_team_ps
# Out:
#        raceId  driverId  stop  lap    seconds  milliseconds  constructorId
# 0         841       153     1    1     26.898         26898              5
# 1         841       153     2   17     24.463         24463              5
# 2         841       153     3   35     26.348         26348              5
# 3         841        30     1    1     25.021         25021            131
# 4         841        30     2   17     23.988         23988            131
# ...       ...       ...   ...  ...        ...           ...            ...
# 10853    1128       822     1    1  39:54.053       2394053             15
# 10854    1128       822    15    2     24.239         24239             15
# 10855    1128       832     1    1  38:47.072       2327072              6
# 10856    1128       855     1    1  39:46.414       2386414             15
# 10857    1128       855    70    2     24.367         24367             15
#
# [10858 rows x 7 columns]

# %%
driver_missing_team_ps = pd.merge(missing_driver_missing_team_ps, drivers_df, on=['driverId'], how='inner')
driver_missing_team_ps
# Out:
#        raceId  driverId  stop  lap seconds  milliseconds  constructorId  \
# 0         841       153     1    1  26.898         26898              5
# 1         841       153     2   17  24.463         24463              5
# 2         841       153     3   35  26.348         26348              5
# 3         842       153     1   16  23.584         23584              5
# 4         842       153     2   32  22.888         22888              5
# ...       ...       ...   ...  ...     ...           ...            ...
# 10853    1114       859     2   25  23.671         23671            213
# 10854    1115       859     1    3  29.330         29330            213
# 10855    1115       859     2   21  28.665         28665            213
# 10856    1115       859     3   39  28.171         28171            213
# 10857    1122       860     1    7  22.457         22457              6
#
#       number firstname     lastname         dob
# 0         \N     Jaime  Alguersuari  1990-03-23
# 1         \N     Jaime  Alguersuari  1990-03-23
# 2         \N     Jaime  Alguersuari  1990-03-23
# 3         \N     Jaime  Alguersuari  1990-03-23
# 4         \N     Jaime  Alguersuari  1990-03-23
# ...      ...       ...          ...         ...
# 10853     40      Liam       Lawson  2002-02-11
# 10854     40      Liam       Lawson  2002-02-11
# 10855     40      Liam       Lawson  2002-02-11
# 10856     40      Liam       Lawson  2002-02-11
# 10857     38    Oliver      Bearman  2005-05-08
#
# [10858 rows x 11 columns]

# %%
df_driver_team_ps = pd.merge(driver_missing_team_ps, constructors_df, on=['constructorId'], how='inner')
df_driver_team_ps
# Out:
#        raceId  driverId  stop  lap    seconds  milliseconds  constructorId  \
# 0         841       153     1    1     26.898         26898              5
# 1         841       153     2   17     24.463         24463              5
# 2         841       153     3   35     26.348         26348              5
# 3         842       153     1   16     23.584         23584              5
# 4         842       153     2   32     22.888         22888              5
# ...       ...       ...   ...  ...        ...           ...            ...
# 10853     966       839     1   15     23.866         23866            209
# 10854     967       839     1   20  33:29.052       2009052            209
# 10855     967       839     2   28  24:45.092       1485092            209
# 10856     968       839     1   22     24.035         24035            209
# 10857     968       839     2   36     23.026         23026            209
#
#       number firstname     lastname         dob        teamname
# 0         \N     Jaime  Alguersuari  1990-03-23      Toro Rosso
# 1         \N     Jaime  Alguersuari  1990-03-23      Toro Rosso
# 2         \N     Jaime  Alguersuari  1990-03-23      Toro Rosso
# 3         \N     Jaime  Alguersuari  1990-03-23      Toro Rosso
# 4         \N     Jaime  Alguersuari  1990-03-23      Toro Rosso
# ...      ...       ...          ...         ...             ...
# 10853     31   Esteban         Ocon  1996-09-17  Manor Marussia
# 10854     31   Esteban         Ocon  1996-09-17  Manor Marussia
# 10855     31   Esteban         Ocon  1996-09-17  Manor Marussia
# 10856     31   Esteban         Ocon  1996-09-17  Manor Marussia
# 10857     31   Esteban         Ocon  1996-09-17  Manor Marussia
#
# [10858 rows x 12 columns]

# %%
df_driver_team_race_ps = pd.merge(df_driver_team_ps, races_df, on=['raceId'], how='inner')
df_driver_team_race_ps
# Out:
#      raceId  driverId  stop  lap seconds  milliseconds  constructorId number  \
# 0      1098         1     1   12  24.682         24682            131     44
# 1      1098         1     2   30  24.690         24690            131     44
# 2      1098       847     1   13  27.062         27062            131     63
# 3      1098       847     2   31  24.406         24406            131     63
# 4      1098       815     1   17  24.264         24264              9     11
# ..      ...       ...   ...  ...     ...           ...            ...    ...
# 907    1115       807     2   27  28.274         28274            210     27
# 908    1115       807     3   39  28.591         28591            210     27
# 909    1115       825     1    3  28.743         28743            210     20
# 910    1115       825     2   21  28.948         28948            210     20
# 911    1115       825     3   39  30.331         30331            210     20
#
#     firstname    lastname         dob      teamname  year  round  circuitId  \
# 0       Lewis    Hamilton  1985-01-07      Mercedes  2023      1          3
# 1       Lewis    Hamilton  1985-01-07      Mercedes  2023      1          3
# 2      George     Russell  1998-02-15      Mercedes  2023      1          3
# 3      George     Russell  1998-02-15      Mercedes  2023      1          3
# 4      Sergio       Pérez  1990-01-26      Red Bull  2023      1          3
# ..        ...         ...         ...           ...   ...    ...        ...
# 907      Nico  Hülkenberg  1987-08-19  Haas F1 Team  2023     17         78
# 908      Nico  Hülkenberg  1987-08-19  Haas F1 Team  2023     17         78
# 909     Kevin   Magnussen  1992-10-05  Haas F1 Team  2023     17         78
# 910     Kevin   Magnussen  1992-10-05  Haas F1 Team  2023     17         78
# 911     Kevin   Magnussen  1992-10-05  Haas F1 Team  2023     17         78
#
#                  gpname        date
# 0    Bahrain Grand Prix  2023-03-05
# 1    Bahrain Grand Prix  2023-03-05
# 2    Bahrain Grand Prix  2023-03-05
# 3    Bahrain Grand Prix  2023-03-05
# 4    Bahrain Grand Prix  2023-03-05
# ..                  ...         ...
# 907    Qatar Grand Prix  2023-10-08
# 908    Qatar Grand Prix  2023-10-08
# 909    Qatar Grand Prix  2023-10-08
# 910    Qatar Grand Prix  2023-10-08
# 911    Qatar Grand Prix  2023-10-08
#
# [912 rows x 17 columns]

# %%
df_ferrari_ps = df_driver_team_race_ps.loc[df_driver_team_race_ps['teamname'] == 'Ferrari'].reset_index(drop=True)
df_ferrari_ps.columns = df_ferrari_ps.columns.str.strip() # to remove whitespace in headers

df_ferrari_ps['firstname'] = df_ferrari_ps['firstname'].str.strip()
df_ferrari_ps['lastname'] = df_ferrari_ps['lastname'].str.strip()
df_ferrari_ps['teamname'] = df_ferrari_ps['teamname'].str.strip()
df_ferrari_ps['gpname'] = df_ferrari_ps['gpname'].str.strip()

df_ferrari_ps = df_ferrari_ps.replace(np.nan, '')

# %%
df_ferrari_ps
# Out:
#     raceId  driverId  stop  lap seconds  milliseconds  constructorId number  \
# 0     1098       832     1   13  24.500         24500              6     55
# 1     1098       832     2   31  24.227         24227              6     55
# 2     1098       844     1   13  24.345         24345              6     16
# 3     1098       844     2   33  24.644         24644              6     16
# 4     1099       832     1   15  20.760         20760              6     55
# ..     ...       ...   ...  ...     ...           ...            ...    ...
# 71    1120       844     1   17  21.919         21919              6     16
# 72    1120       844     2   35  21.246         21246              6     16
# 73    1115       844     1   12  28.228         28228              6     16
# 74    1115       844     2   25  27.873         27873              6     16
# 75    1115       844     3   43  27.513         27513              6     16
#
#    firstname lastname         dob teamname  year  round  circuitId  \
# 0     Carlos    Sainz  1994-09-01  Ferrari  2023      1          3
# 1     Carlos    Sainz  1994-09-01  Ferrari  2023      1          3
# 2    Charles  Leclerc  1997-10-16  Ferrari  2023      1          3
# 3    Charles  Leclerc  1997-10-16  Ferrari  2023      1          3
# 4     Carlos    Sainz  1994-09-01  Ferrari  2023      2         77
# ..       ...      ...         ...      ...   ...    ...        ...
# 71   Charles  Leclerc  1997-10-16  Ferrari  2023     22         24
# 72   Charles  Leclerc  1997-10-16  Ferrari  2023     22         24
# 73   Charles  Leclerc  1997-10-16  Ferrari  2023     17         78
# 74   Charles  Leclerc  1997-10-16  Ferrari  2023     17         78
# 75   Charles  Leclerc  1997-10-16  Ferrari  2023     17         78
#
#                       gpname        date
# 0         Bahrain Grand Prix  2023-03-05
# 1         Bahrain Grand Prix  2023-03-05
# 2         Bahrain Grand Prix  2023-03-05
# 3         Bahrain Grand Prix  2023-03-05
# 4   Saudi Arabian Grand Prix  2023-03-19
# ..                       ...         ...
# 71      Abu Dhabi Grand Prix  2023-11-26
# 72      Abu Dhabi Grand Prix  2023-11-26
# 73          Qatar Grand Prix  2023-10-08
# 74          Qatar Grand Prix  2023-10-08
# 75          Qatar Grand Prix  2023-10-08
#
# [76 rows x 17 columns]

# %%
gp_list = df_ferrari_ps['gpname'].unique().tolist()
gp_list
# Out:
# ['Bahrain Grand Prix',
#  'Saudi Arabian Grand Prix',
#  'Australian Grand Prix',
#  'Azerbaijan Grand Prix',
#  'Miami Grand Prix',
#  'Monaco Grand Prix',
#  'Spanish Grand Prix',
#  'Canadian Grand Prix',
#  'Austrian Grand Prix',
#  'British Grand Prix',
#  'Hungarian Grand Prix',
#  'Belgian Grand Prix',
#  'Dutch Grand Prix',
#  'Italian Grand Prix',
#  'Singapore Grand Prix',
#  'Japanese Grand Prix',
#  'United States Grand Prix',
#  'Mexico City Grand Prix',
#  'São Paulo Grand Prix',
#  'Las Vegas Grand Prix',
#  'Abu Dhabi Grand Prix',
#  'Qatar Grand Prix']

# %%
for gp in gp_list:
    df_gp_carlos = df_ferrari_ps.loc[(df_ferrari_ps['gpname'] == f'{gp}') & (df_ferrari_ps['firstname'] == 'Carlos')].reset_index(drop=True)
    df_gp_charles = df_ferrari_ps.loc[(df_ferrari_ps['gpname'] == f'{gp}') & (df_ferrari_ps['firstname'] == 'Charles')].reset_index(drop=True)
    pit_time_carlos = df_gp_carlos['seconds'].min()
    pit_time_charles = df_gp_charles['seconds'].min()
    print(f'Carlos fastest pit time in {gp} is {pit_time_carlos}')
    print(f'Charles fastest pit time in {gp} is {pit_time_charles}')
# Out:
# Carlos fastest pit time in Bahrain Grand Prix is 24.227
# Charles fastest pit time in Bahrain Grand Prix is 24.345
# Carlos fastest pit time in Saudi Arabian Grand Prix is 20.760
# Charles fastest pit time in Saudi Arabian Grand Prix is 20.026
# Carlos fastest pit time in Australian Grand Prix is 14:34.924
# Charles fastest pit time in Australian Grand Prix is nan
# Carlos fastest pit time in Azerbaijan Grand Prix is 21.970
# Charles fastest pit time in Azerbaijan Grand Prix is 21.126
# Carlos fastest pit time in Miami Grand Prix is 22.278
# Charles fastest pit time in Miami Grand Prix is 22.068
# Carlos fastest pit time in Monaco Grand Prix is 24.252
# Charles fastest pit time in Monaco Grand Prix is 24.192
# Carlos fastest pit time in Spanish Grand Prix is 22.321
# Charles fastest pit time in Spanish Grand Prix is 21.778
# Carlos fastest pit time in Canadian Grand Prix is 24.133
# Charles fastest pit time in Canadian Grand Prix is 24.343
# Carlos fastest pit time in Austrian Grand Prix is 16.380
# Charles fastest pit time in Austrian Grand Prix is 16.393
# Carlos fastest pit time in British Grand Prix is 28.869
# Charles fastest pit time in British Grand Prix is 28.244
# Carlos fastest pit time in Hungarian Grand Prix is 21.402
# Charles fastest pit time in Hungarian Grand Prix is 21.452
# Carlos fastest pit time in Belgian Grand Prix is 23.303
# Charles fastest pit time in Belgian Grand Prix is 23.148
# Carlos fastest pit time in Dutch Grand Prix is 19.398
# Charles fastest pit time in Dutch Grand Prix is 27.202
# Carlos fastest pit time in Italian Grand Prix is 25.183
# Charles fastest pit time in Italian Grand Prix is 23.931
# Carlos fastest pit time in Singapore Grand Prix is 29.499
# Charles fastest pit time in Singapore Grand Prix is 32.888
# Carlos fastest pit time in Japanese Grand Prix is 23.075
# Charles fastest pit time in Japanese Grand Prix is 22.926
# Carlos fastest pit time in United States Grand Prix is 23.668
# Charles fastest pit time in United States Grand Prix is 23.963
# Carlos fastest pit time in Mexico City Grand Prix is 20:15.432
# Charles fastest pit time in Mexico City Grand Prix is 20:10.512
# Carlos fastest pit time in São Paulo Grand Prix is 23.030
# Charles fastest pit time in São Paulo Grand Prix is nan
# Carlos fastest pit time in Las Vegas Grand Prix is 21.261
# Charles fastest pit time in Las Vegas Grand Prix is 22.559
# Carlos fastest pit time in Abu Dhabi Grand Prix is 21.229
# Charles fastest pit time in Abu Dhabi Grand Prix is 21.246
# Carlos fastest pit time in Qatar Grand Prix is nan
# Charles fastest pit time in Qatar Grand Prix is 27.513
