# %%
import pandas as pd
import numpy as np

from datetime import datetime
from datetime import time

pd.options.display.max_columns = None

# %% [markdown]
# # Easy View of all dataset CSV files without the need to open them in spreadsheet

# %%
# All race tracks in F1 
circuit_df = pd.read_csv('f1db_csv/circuits.csv', index_col=False)
circuit_df
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# ...

# %%
# F1 Team results
contructor_results_df = pd.read_csv('f1db_csv/constructor_results.csv', index_col=False)
contructor_results_df
# Out:
#        constructorResultsId  raceId  constructorId  points status
# 0                         1      18              1    14.0     \N
# 1                         2      18              2     8.0     \N
# 2                         3      18              3     9.0     \N
# 3                         4      18              4     5.0     \N
# 4                         5      18              5     2.0     \N
# ...                     ...     ...            ...     ...    ...
# 12470                 16975    1129            214     3.0     \N
# 12471                 16976    1129            210     0.0     \N
# 12472                 16977    1129             15     0.0     \N
# 12473                 16978    1129              6     0.0     \N
# 12474                 16979    1129              3     0.0     \N
#
# [12475 rows x 5 columns]

# %%
# F1 Team standing
constructor_standings_df = pd.read_csv('f1db_csv/constructor_standings.csv', index_col=False)
constructor_standings_df
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 0                           1      18              1    14.0         1
# 1                           2      18              2     8.0         3
# 2                           3      18              3     9.0         2
# 3                           4      18              4     5.0         4
# 4                           5      18              5     2.0         5
# ...                       ...     ...            ...     ...       ...
# 13236                   28818    1129             15     0.0        10
# 13237                   28819    1129            210     7.0         7
# 13238                   28820    1129            215    28.0         6
# 13239                   28821    1129              3     2.0         9
# 13240                   28822    1129            214     5.0         8
#
#       positionText  wins
# 0                1     1
# 1                3     0
# 2                2     0
# ...

# %%
# F1 Team reference
## Use 'constructorId' for team match 
constructors_df = pd.read_csv('f1db_csv/constructors.csv', index_col=False)
constructors_df
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
# 211            215             rb      RB F1 Team     Italian
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# ...

# %%
# Individual Driver F1 standing
driver_standings_df = pd.read_csv('f1db_csv/driver_standings.csv', index_col=False)
driver_standings_df
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 34527              72804    1129       839     2.0        17           17
# 34528              72805    1129       842     3.0        15           15
# 34529              72806    1129       822     0.0        20           20
# 34530              72807    1129       858     0.0        21           21
# 34531              72808    1129       860     6.0        13           13
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# ...

# %%
drivers_df = pd.read_csv('f1db_csv/drivers.csv', index_col=False)
drivers_df
# Out:
#      driverId   driverRef number code  forename     surname         dob  \
# 0           1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...         ...    ...  ...       ...         ...         ...
# 854       856    de_vries     21  DEV      Nyck    de Vries  1995-02-06
# 855       857     piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858    sargeant      2  SAR     Logan    Sargeant  2000-12-31
# 857       859      lawson     40  LAW      Liam      Lawson  2002-02-11
# 858       860     bearman     38  BEA    Oliver     Bearman  2005-05-08
#
#        nationality                                             url
# ...

# %%
lap_times_csv = pd.read_csv('f1db_csv/lap_times.csv', index_col=False)
lap_times_csv
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 0          841        20    1         1  1:38.109         98109
# 1          841        20    2         1  1:33.006         93006
# 2          841        20    3         1  1:32.713         92713
# 3          841        20    4         1  1:32.803         92803
# 4          841        20    5         1  1:32.342         92342
# ...        ...       ...  ...       ...       ...           ...
# 572309    1129       855   65        15  1:20.871         80871
# 572310    1129       855   66        15  1:18.762         78762
# 572311    1129       855   67        15  1:18.258         78258
# 572312    1129       855   68        15  1:17.325         77325
# 572313    1129       855   69        15  1:17.620         77620
#
# [572314 rows x 6 columns]

# %%
# Pit stop time by team and race (reference back using raceId and DriverId above)
pit_stops_df = pd.read_csv('f1db_csv/pit_stops.csv', index_col=False)
pit_stops_df
# Out:
#        raceId  driverId  stop  lap      time duration  milliseconds
# 0         841       153     1    1  17:05:23   26.898         26898
# 1         841        30     1    1  17:05:52   25.021         25021
# 2         841        17     1   11  17:20:48   23.426         23426
# 3         841         4     1   12  17:22:34   23.251         23251
# 4         841        13     1   13  17:24:10   23.842         23842
# ...       ...       ...   ...  ...       ...      ...           ...
# 10853    1128       840    48    3  16:49:27   28.211         28211
# 10854    1128         1    51    2  16:52:10   24.232         24232
# 10855    1128       830    52    2  16:53:26   23.813         23813
# 10856    1128       858    57    2  17:01:43   24.384         24384
# 10857    1128       855    70    2  17:19:04   24.367         24367
#
# [10858 rows x 7 columns]

# %%
# Qualifying times (reference back using raceId and driverId above)
qualifying_df = pd.read_csv('f1db_csv/qualifying.csv', index_col=False)
qualifying_df
# Out:
#        qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0              1      18         1              1      22         1  1:26.572
# 1              2      18         9              2       4         2  1:26.103
# 2              3      18         5              1      23         3  1:25.664
# 3              4      18        13              6       2         4  1:25.994
# 4              5      18         2              2       3         5  1:25.960
# ...          ...     ...       ...            ...     ...       ...       ...
# 10189      10247    1129       815              9      11        16  1:13.326
# 10190      10248    1129       822             15      77        17  1:13.366
# 10191      10249    1129       839            214      31        18  1:13.435
# 10192      10250    1129       807            210      27        19  1:13.978
# 10193      10251    1129       855             15      24        20  1:14.292
#
#              q2        q3
# ...

# %%
# All F1 races from 2009 to Current (dataset will be deprecated by 2024)
races_df = pd.read_csv('f1db_csv/races.csv', index_col=False)
races_df
# Out:
#       raceId  year  round  circuitId                    name        date  \
# 0          1  2009      1          1   Australian Grand Prix  2009-03-29
# 1          2  2009      2          2    Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17      Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3      Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4      Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                     ...         ...
# 1120    1140  2024     20         32  Mexico City Grand Prix  2024-10-27
# 1121    1141  2024     21         18    São Paulo Grand Prix  2024-11-03
# 1122    1142  2024     22         80    Las Vegas Grand Prix  2024-11-23
# 1123    1143  2024     23         78        Qatar Grand Prix  2024-12-01
# 1124    1144  2024     24         24    Abu Dhabi Grand Prix  2024-12-08
#
#           time                                                url    fp1_date  \
# ...

# %%
races_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   raceId       1125 non-null   int64
#  1   year         1125 non-null   int64
#  2   round        1125 non-null   int64
#  3   circuitId    1125 non-null   int64
#  4   name         1125 non-null   object
#  5   date         1125 non-null   object
#  6   time         1125 non-null   object
#  7   url          1125 non-null   object
#  8   fp1_date     1125 non-null   object
#  9   fp1_time     1125 non-null   object
#  10  fp2_date     1125 non-null   object
#  11  fp2_time     1125 non-null   object
#  12  fp3_date     1125 non-null   object
#  13  fp3_time     1125 non-null   object
#  14  quali_date   1125 non-null   object
#  15  quali_time   1125 non-null   object
#  16  sprint_date  1125 non-null   object
#  17  sprint_time  1125 non-null   object
# dtypes: int64(4), object(14)
# ...

# %%
# Race results
results_df = pd.read_csv('f1db_csv/results.csv', index_col=False)
results_df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26454     26460    1129       832              6     55    12       \N
# 26455     26461    1129       848              3     23    10       \N
# 26456     26462    1129       815              9     11    16       \N
# 26457     26463    1129       844              6     16    11       \N
# 26458     26464    1129       858              3      2    13       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
# F1 Race Seasons with wiki reference
seasons_df = pd.read_csv('f1db_csv/seasons.csv', index_col=False)
seasons_df
# Out:
#     year                                                url
# 0   2009  http://en.wikipedia.org/wiki/2009_Formula_One_...
# 1   2008  http://en.wikipedia.org/wiki/2008_Formula_One_...
# 2   2007  http://en.wikipedia.org/wiki/2007_Formula_One_...
# 3   2006  http://en.wikipedia.org/wiki/2006_Formula_One_...
# 4   2005  http://en.wikipedia.org/wiki/2005_Formula_One_...
# ..   ...                                                ...
# 70  2020  http://en.wikipedia.org/wiki/2020_Formula_One_...
# 71  2021  http://en.wikipedia.org/wiki/2021_Formula_One_...
# 72  2022  http://en.wikipedia.org/wiki/2022_Formula_One_...
# 73  2023  http://en.wikipedia.org/wiki/2023_Formula_One_...
# 74  2024  https://en.wikipedia.org/wiki/2024_Formula_One...
#
# [75 rows x 2 columns]

# %%
# F1 sprint results
sprint_results_df = pd.read_csv('f1db_csv/sprint_results.csv', index_col=False)
sprint_results_df
# Out:
#      resultId  raceId  driverId  constructorId  number  grid position  \
# 0           1    1061       830              9      33     2        1
# 1           2    1061         1            131      44     1        2
# 2           3    1061       822            131      77     3        3
# 3           4    1061       844              6      16     4        4
# 4           5    1061       846              1       4     6        5
# ..        ...     ...       ...            ...     ...   ...      ...
# 275       276    1126         1            131      44    12       16
# 276       277    1126         4            117      14     8       17
# 277       278    1126       825            210      20    14       18
# 278       279    1126       840            117      18     7       19
# 279       280    1126       846              1       4     9       20
#
#     positionText  positionOrder  points  laps       time milliseconds  \
# ...

# %%
# How the driver finished the race. Ex/ Finished, Disqualified, Accident, Illness, car issues (Engine, Cooling system, etc.), or other underlying issues)
status_df = pd.read_csv('f1db_csv/status.csv', index_col=False)
status_df
# Out:
#      statusId          status
# 0           1        Finished
# 1           2    Disqualified
# 2           3        Accident
# 3           4       Collision
# 4           5          Engine
# ..        ...             ...
# 134       137          Damage
# 135       138          Debris
# 136       139         Illness
# 137       140       Undertray
# 138       141  Cooling system
#
# [139 rows x 2 columns]
